# %% [markdown]
# ### 183. Customers Who Never Order

# %% [markdown]
# ### Write a solution to find all customers who never order anything

# %%
# %sql
CREATE TABLE Customers (
    id INT,
    name VARCHAR(255)
);

CREATE TABLE Orders (
    id INT,
    customerId INT
);

# %%
# %sql
-- Inserting into Customers
INSERT INTO Customers (id, name) VALUES (1, 'Joe');
INSERT INTO Customers (id, name) VALUES (2, 'Henry');
INSERT INTO Customers (id, name) VALUES (3, 'Sam');
INSERT INTO Customers (id, name) VALUES (4, 'Max');

-- Inserting into Orders
INSERT INTO Orders (id, customerId) VALUES (1, 3);
INSERT INTO Orders (id, customerId) VALUES (2, 1);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
select * from Customers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th></tr></thead><tbody><tr><td>2</td><td>Henry</td></tr><tr><td>3</td><td>Sam</td></tr><tr><td>4</td><td>Max</td></tr><tr><td>1</td><td>Joe</td></tr></tbody></table></div>

# %%
# %sql
select * from Orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>customerId</th></tr></thead><tbody><tr><td>2</td><td>1</td></tr><tr><td>1</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
select * from Customers c left join Orders o on c.id =o.customerId where o.customerId is null;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>id</th><th>customerId</th></tr></thead><tbody><tr><td>2</td><td>Henry</td><td>null</td><td>null</td></tr><tr><td>4</td><td>Max</td><td>null</td><td>null</td></tr></tbody></table></div>
